# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("commuting_with_cluster_percentage.csv")

print(df.head())
print(df.info())
# Out:
#    percentage_0  percentage_1_14  percentage_15_29  percentage_30_44  \
# 0          0.00            17.65             29.68             31.28
# 1          4.53             3.30             52.18             33.34
# 2          2.96            55.56             27.97              7.36
# 3          5.77            18.83             29.98             21.08
# 4          8.12            52.14              5.56             32.05
#
#    percentage_under45  percentage_45_59  percentage_60  percentage_over45  \
# 0               78.61              1.34          20.05              21.39
# 1               93.35              0.43           6.22               6.65
# 2               93.85              2.45           3.70               6.15
# 3               75.66             10.59          13.75              24.34
# 4               97.87              0.85           1.28               2.13
#
#         Region cluster_label urbanisation_degree        education_level  \
# 0       Latvia        Low-HO              Cities              ISCED 3–4
# 1       Poland        Mid-HO               Total              ISCED 5–8
# 2  Netherlands       High-HO               Total              ISCED 0–2
# 3  Netherlands       High-HO               Total  All ISCED 2011 levels
# 4      Croatia        Low-HO               Total              ISCED 3–4
#
#   age_class     sex
# 0     50-74  female
# 1     50-74  female
# 2     15-34  female
# 3     35-49    male
# 4     15-34  female
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1703 entries, 0 to 1702
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   percentage_0         1703 non-null   float64
#  1   percentage_1_14      1703 non-null   float64
#  2   percentage_15_29     1703 non-null   float64
#  3   percentage_30_44     1703 non-null   float64
#  4   percentage_under45   1703 non-null   float64
#  5   percentage_45_59     1703 non-null   float64
#  6   percentage_60        1703 non-null   float64
#  7   percentage_over45    1703 non-null   float64
#  8   Region               1703 non-null   object
#  9   cluster_label        1703 non-null   object
#  10  urbanisation_degree  1703 non-null   object
#  11  education_level      1703 non-null   object
#  12  age_class            1703 non-null   object
#  13  sex                  1703 non-null   object
# dtypes: float64(8), object(6)
# memory usage: 186.4+ KB
# None

# %%
for col in ["education_level", "urbanisation_degree", "cluster_label"]:
    print(col, df[col].unique())
# Out:
# education_level ['ISCED 3–4' 'ISCED 5–8' 'ISCED 0–2' 'All ISCED 2011 levels']
# urbanisation_degree ['Cities' 'Total' 'Rural areas' 'Towns and suburbs' 'No response']
# cluster_label ['Low-HO' 'Mid-HO' 'High-HO']

# %%
# Drop rows
df = df[
    (~df['education_level'].str.contains("All ISCED", case=False, na=False)) &
    (~df['urbanisation_degree'].str.contains("Total", case=False, na=False)) &
    (~df['urbanisation_degree'].str.contains("No response", case=False, na=False))
]

# Reset index
df = df.reset_index(drop=True)

# %%
print(df['urbanisation_degree'].unique())
print(df['education_level'].unique())
# Out:
# ['Cities' 'Towns and suburbs' 'Rural areas']
# ['ISCED 3–4' 'ISCED 5–8' 'ISCED 0–2']

# %%
for col in ["education_level", "urbanisation_degree", "cluster_label", "Region"]:
    df[col] = df[col].astype("category")

# %%
df['percentage_over45'] = pd.to_numeric(df['percentage_over45'], errors='coerce')

# %%
# model with interaction
md = smf.mixedlm(
    "percentage_over45 ~ C(education_level) * C(urbanisation_degree) * C(cluster_label)",
    data=df,
    groups=df["Region"],          
    re_formula="~1"
)
mfit = md.fit()
print(mfit.summary())
# Out:
#                                                        Mixed Linear Model Regression Results
# ===================================================================================================================================================
# Model:                                        MixedLM                             Dependent Variable:                             percentage_over45
# No. Observations:                             697                                 Method:                                         REML
# No. Groups:                                   23                                  Scale:                                          49.1496
# Min. group size:                              4                                   Log-Likelihood:                                 -2319.7342
# Max. group size:                              54                                  Converged:                                      Yes
# Mean group size:                              30.3
# ---------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                                                         Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                5.165    2.826  1.828 0.068  -0.373 10.703
# C(education_level)[T.ISCED 3–4]                                                                          6.174    2.531  2.439 0.015   1.213 11.135
# C(education_level)[T.ISCED 5–8]                                                                         12.201    2.491  4.898 0.000   7.319 17.082
# C(urbanisation_degree)[T.Rural areas]                                                                   -1.564    3.384 -0.462 0.644  -8.198  5.069
# C(urbanisation_degree)[T.Towns and suburbs]                                                              0.171    2.865  0.060 0.953  -5.445  5.786
# C(cluster_label)[T.Low-HO]                                                                               4.375    3.675  1.190 0.234  -2.829 11.579
# C(cluster_label)[T.Mid-HO]                                                                               7.764    4.449  1.745 0.081  -0.957 16.485
# C(education_level)[T.ISCED 3–4]:C(urbanisation_degree)[T.Rural areas]                                   -0.638    3.940 -0.162 0.871  -8.361  7.085
# C(education_level)[T.ISCED 5–8]:C(urbanisation_degree)[T.Rural areas]                                    2.867    4.021  0.713 0.476  -5.014 10.748
# C(education_level)[T.ISCED 3–4]:C(urbanisation_degree)[T.Towns and suburbs]                             -0.607    3.505 -0.173 0.862  -7.476  6.262
# C(education_level)[T.ISCED 5–8]:C(urbanisation_degree)[T.Towns and suburbs]                              1.694    3.527  0.480 0.631  -5.218  8.606
# C(education_level)[T.ISCED 3–4]:C(cluster_label)[T.Low-HO]                                              -2.538    3.352 -0.757 0.449  -9.107  4.032
# C(education_level)[T.ISCED 5–8]:C(cluster_label)[T.Low-HO]                                              -6.425    3.325 -1.932 0.053 -12.941  0.092
# C(education_level)[T.ISCED 3–4]:C(cluster_label)[T.Mid-HO]                                              -4.994    4.133 -1.208 0.227 -13.094  3.107
# C(education_level)[T.ISCED 5–8]:C(cluster_label)[T.Mid-HO]                                             -10.267    4.102 -2.503 0.012 -18.307 -2.227
# C(urbanisation_degree)[T.Rural areas]:C(cluster_label)[T.Low-HO]                                        -3.580    4.130 -0.867 0.386 -11.675  4.515
# C(urbanisation_degree)[T.Towns and suburbs]:C(cluster_label)[T.Low-HO]                                  -2.979    3.827 -0.778 0.436 -10.479  4.521
# C(urbanisation_degree)[T.Rural areas]:C(cluster_label)[T.Mid-HO]                                        -9.025    4.888 -1.846 0.065 -18.606  0.556
# C(urbanisation_degree)[T.Towns and suburbs]:C(cluster_label)[T.Mid-HO]                                 -12.508    4.975 -2.514 0.012 -22.259 -2.757
# C(education_level)[T.ISCED 3–4]:C(urbanisation_degree)[T.Rural areas]:C(cluster_label)[T.Low-HO]         2.468    4.800  0.514 0.607  -6.940 11.875
# C(education_level)[T.ISCED 5–8]:C(urbanisation_degree)[T.Rural areas]:C(cluster_label)[T.Low-HO]        -4.007    5.014 -0.799 0.424 -13.834  5.820
# C(education_level)[T.ISCED 3–4]:C(urbanisation_degree)[T.Towns and suburbs]:C(cluster_label)[T.Low-HO]  -1.759    4.560 -0.386 0.700 -10.695  7.178
# C(education_level)[T.ISCED 5–8]:C(urbanisation_degree)[T.Towns and suburbs]:C(cluster_label)[T.Low-HO]  -0.795    4.627 -0.172 0.864  -9.864  8.273
# C(education_level)[T.ISCED 3–4]:C(urbanisation_degree)[T.Rural areas]:C(cluster_label)[T.Mid-HO]         4.761    5.541  0.859 0.390  -6.099 15.621
# C(education_level)[T.ISCED 5–8]:C(urbanisation_degree)[T.Rural areas]:C(cluster_label)[T.Mid-HO]         6.040    5.647  1.070 0.285  -5.029 17.108
# C(education_level)[T.ISCED 3–4]:C(urbanisation_degree)[T.Towns and suburbs]:C(cluster_label)[T.Mid-HO]   5.407    5.653  0.956 0.339  -5.673 16.487
# C(education_level)[T.ISCED 5–8]:C(urbanisation_degree)[T.Towns and suburbs]:C(cluster_label)[T.Mid-HO]   6.611    5.674  1.165 0.244  -4.510 17.733
# Group Var                                                                                               17.275    0.906
# ===================================================================================================================================================

# %%
#model without interaction
md = smf.mixedlm(
    "percentage_over45 ~ C(education_level) + C(urbanisation_degree) + C(cluster_label)",
    data=df,
    groups=df["Region"]
)
mfit = md.fit()
print(mfit.summary())
# Out:
#                         Mixed Linear Model Regression Results
# ======================================================================================
# Model:                     MixedLM        Dependent Variable:        percentage_over45
# No. Observations:          697            Method:                    REML
# No. Groups:                23             Scale:                     51.5243
# Min. group size:           4              Log-Likelihood:            -2379.0962
# Max. group size:           54             Converged:                 Yes
# Mean group size:           30.3
# --------------------------------------------------------------------------------------
#                                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------------
# Intercept                                    9.307    2.123  4.384 0.000  5.146 13.468
# C(education_level)[T.ISCED 3–4]              4.659    0.840  5.545 0.000  3.012  6.306
# C(education_level)[T.ISCED 5–8]              8.695    0.860 10.105 0.000  7.008 10.381
# C(urbanisation_degree)[T.Rural areas]       -3.414    0.679 -5.028 0.000 -4.745 -2.083
# C(urbanisation_degree)[T.Towns and suburbs] -3.261    0.676 -4.823 0.000 -4.586 -1.936
# C(cluster_label)[T.Low-HO]                  -1.697    2.378 -0.714 0.476 -6.359  2.965
# C(cluster_label)[T.Mid-HO]                  -2.563    2.565 -0.999 0.318 -7.591  2.464
# Group Var                                   16.933    0.877
# ======================================================================================

# %% [markdown]
# Education matters a lot: higher education strongly predicts longer commutes (very significant).
#
# Urbanisation also matters: people in cities commute longer than those in rural/towns.
#
# HO cluster is not significant here → whether a country is high/low/mid home-office doesn’t affect long commuting rates much once you control for education and urbanisation.
#
# Random effects: variance across countries still meaningful (countries differ beyond education/urbanisation)

# %%
pred_df = pd.DataFrame([
    (edu, urb, clust, reg)
    for edu in df["education_level"].unique()
    for urb in df["urbanisation_degree"].unique()
    for clust in df["cluster_label"].unique()
    for reg in df["Region"].unique()[:1]  # pick 1 region just for prediction baseline
], columns=["education_level", "urbanisation_degree", "cluster_label", "Region"])

# Get predicted means
pred_df["predicted"] = mfit.predict(pred_df)

# Plot: Education × Urbanisation, colored by cluster
plt.figure(figsize=(10,6))
sns.pointplot(
    data=pred_df,
    x="education_level",
    y="predicted",
    hue="urbanisation_degree",
    dodge=True,
    markers="o",
    capsize=.1,
    errwidth=1,
)
plt.title("Predicted % of commuters >45min by Education and Urbanisation")
plt.ylabel("% commuters >45 min")
plt.xlabel("Education Level")
plt.legend(title="Urbanisation Degree")
plt.show()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_21564\1967337385.py:14: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   sns.pointplot(
